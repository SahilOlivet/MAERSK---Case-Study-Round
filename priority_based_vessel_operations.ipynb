# %% [markdown]
# # Simulating Priority-Based Vessel Operations with Manual Resource Management at a Shipping Terminal Using SimPy
# #### Note: Manual Control Over Resource Release, Resource requests made without using 'with' satement

# %%
import simpy
import random
import heapq

# %% [markdown]
# #### Constants

# %%
AVG_ARRIVAL_TIME = 5 * 60  # Average arrival time in minutes (5 hours)
CONTAINER_COUNT = 150 # Provided number of containers in each vessel
CRANE_MOVE_TIME = 3  # Crane move time per container in minutes
TRUCK_ROUND_TRIP_TIME = 6  # Truck round trip time in minutes
SIMULATION_TIME = 24 * 60  # Simulation time in minutes (24 hours)

# %% [markdown]
# #### Time conversion function

# %%
def convert_minutes_to_hhmm(minutes):
    hours = int(minutes // 60)
    minutes = int(minutes % 60)
    return hours, minutes

# %% [markdown]
# #### Priority Request

# %%
# Priority Resource Request
class PriorityRequest:
    def __init__(self, priority, item):
        self.priority = priority
        self.item = item

    def __lt__(self, other):
        return self.priority < other.priority

# %% [markdown]
# #### Main function

# %%
# Functions
def vessel(env, name, priority, terminal):
    arrival_time = env.now
    arrival_hours, arrival_minutes = convert_minutes_to_hhmm(arrival_time)
    print(f"{name} (Priority {priority}) arrives at {arrival_hours} hours and {arrival_minutes} minutes")

    # Request berth with priority
    berth_req = PriorityRequest(priority, terminal.berths.request())
    heapq.heappush(terminal.berth_queue, berth_req)
    yield berth_req.item

    berthing_time = env.now
    berthing_hours, berthing_minutes = convert_minutes_to_hhmm(berthing_time)
    waiting_time = berthing_time - arrival_time
    waiting_hours, waiting_minutes = convert_minutes_to_hhmm(waiting_time)
    print(f"{name} berths at {berthing_hours} hours and {berthing_minutes} minutes after waiting for {waiting_hours} hours and {waiting_minutes} minutes")

    try:
        # Start unloading containers
        for i in range(CONTAINER_COUNT):
            # Request crane with priority
            crane_req = PriorityRequest(priority, terminal.cranes.request())
            heapq.heappush(terminal.crane_queue, crane_req)
            yield crane_req.item

            container_time = env.now
            container_hours, container_minutes = convert_minutes_to_hhmm(container_time)
            print(f"{name}: Crane starts unloading container {i+1} at {container_hours} hours and {container_minutes} minutes")

            # Move container
            yield env.timeout(CRANE_MOVE_TIME)

            # Place container on truck with priority
            truck_req = PriorityRequest(priority, terminal.trucks.request())
            heapq.heappush(terminal.truck_queue, truck_req)
            yield truck_req.item

            truck_time = env.now
            truck_hours, truck_minutes = convert_minutes_to_hhmm(truck_time)
            print(f"{name}: Crane places container {i+1} on truck at {truck_hours} hours and {truck_minutes} minutes")

            # Transport container to yard block
            print(f"Truck starts transporting container {i+1} to yard block at {truck_hours} hours and {truck_minutes} minutes")
            yield env.timeout(TRUCK_ROUND_TRIP_TIME)
            return_time = env.now
            return_hours, return_minutes = convert_minutes_to_hhmm(return_time)
            print(f"Truck returns to quay crane at {return_hours} hours and {return_minutes} minutes")

            # Release the truck
            terminal.trucks.release(truck_req.item)

            # Release the crane
            terminal.cranes.release(crane_req.item)

    finally:
        # Release berth
        terminal.berths.release(berth_req.item)
        
        # Vessel departs
        departure_time = env.now
        departure_hours, departure_minutes = convert_minutes_to_hhmm(departure_time)
        print(f"{name} departs at {departure_hours} hours and {departure_minutes} minutes")

# %% [markdown]
# #### Generator function

# %%
def vessel_arrival_generator(env, terminal):
    i = 0
    while True:
        # Yield a timeout that follows an exponential distribution
        yield env.timeout(random.expovariate(1 / AVG_ARRIVAL_TIME))
        priority = random.choice([1, 2])  # Randomly assign a priority (1 or 2)
        env.process(vessel(env, f"Vessel {i+1}", priority, terminal))
        i += 1

# %%
# Terminal Class with Priority Queues
class Terminal:
    def __init__(self, env):
        self.env = env
        self.berths = simpy.Resource(env, capacity=2)
        self.cranes = simpy.Resource(env, capacity=2)
        self.trucks = simpy.Resource(env, capacity=3)
        self.berth_queue = []
        self.crane_queue = []
        self.truck_queue = []

# %% [markdown]
# #### Simulation environment

# %%
# Simulation Setup
env = simpy.Environment()
terminal = Terminal(env)
env.process(vessel_arrival_generator(env, terminal))
env.run(until=SIMULATION_TIME)
# Out:
# Vessel 1 (Priority 2) arrives at 4 hours and 54 minutes
# Vessel 1 berths at 4 hours and 54 minutes after waiting for 0 hours and 0 minutes
# Vessel 1: Crane starts unloading container 1 at 4 hours and 54 minutes
# Vessel 1: Crane places container 1 on truck at 4 hours and 57 minutes
# Truck starts transporting container 1 to yard block at 4 hours and 57 minutes
# Truck returns to quay crane at 5 hours and 3 minutes
# Vessel 1: Crane starts unloading container 2 at 5 hours and 3 minutes
# Vessel 1: Crane places container 2 on truck at 5 hours and 6 minutes
# Truck starts transporting container 2 to yard block at 5 hours and 6 minutes
# Truck returns to quay crane at 5 hours and 12 minutes
# Vessel 1: Crane starts unloading container 3 at 5 hours and 12 minutes
# Vessel 1: Crane places container 3 on truck at 5 hours and 15 minutes
# Truck starts transporting container 3 to yard block at 5 hours and 15 minutes
# Truck returns to quay crane at 5 hours and 21 minutes
# Vessel 1: Crane starts unloading container 4 at 5 hours and 21 minutes
# Vessel 1: Crane places container 4 on truck at 5 hours and 24 minutes
# Truck starts transporting container 4 to yard block at 5 hours and 24 minutes
# Truck returns to quay crane at 5 hours and 30 minutes
# Vessel 1: Crane starts unloading container 5 at 5 hours and 30 minutes
# Vessel 1: Crane places container 5 on truck at 5 hours and 33 minutes
# Truck starts transporting container 5 to yard block at 5 hours and 33 minutes
# Truck returns to quay crane at 5 hours and 39 minutes
# Vessel 1: Crane starts unloading container 6 at 5 hours and 39 minutes
# Vessel 1: Crane places container 6 on truck at 5 hours and 42 minutes
# Truck starts transporting container 6 to yard block at 5 hours and 42 minutes
# Truck returns to quay crane at 5 hours and 48 minutes
# Vessel 1: Crane starts unloading container 7 at 5 hours and 48 minutes
# Vessel 1: Crane places container 7 on truck at 5 hours and 51 minutes
# Truck starts transporting container 7 to yard block at 5 hours and 51 minutes
# Truck returns to quay crane at 5 hours and 57 minutes
# Vessel 1: Crane starts unloading container 8 at 5 hours and 57 minutes
# Vessel 1: Crane places container 8 on truck at 6 hours and 0 minutes
# Truck starts transporting container 8 to yard block at 6 hours and 0 minutes
# Truck returns to quay crane at 6 hours and 6 minutes
# Vessel 1: Crane starts unloading container 9 at 6 hours and 6 minutes
# Vessel 1: Crane places container 9 on truck at 6 hours and 9 minutes
# Truck starts transporting container 9 to yard block at 6 hours and 9 minutes
# Truck returns to quay crane at 6 hours and 15 minutes
# Vessel 1: Crane starts unloading container 10 at 6 hours and 15 minutes
# Vessel 1: Crane places container 10 on truck at 6 hours and 18 minutes
# Truck starts transporting container 10 to yard block at 6 hours and 18 minutes
# Truck returns to quay crane at 6 hours and 24 minutes
# Vessel 1: Crane starts unloading container 11 at 6 hours and 24 minutes
# Vessel 1: Crane places container 11 on truck at 6 hours and 27 minutes
# Truck starts transporting container 11 to yard block at 6 hours and 27 minutes
# Truck returns to quay crane at 6 hours and 33 minutes
# Vessel 1: Crane starts unloading container 12 at 6 hours and 33 minutes
# Vessel 1: Crane places container 12 on truck at 6 hours and 36 minutes
# Truck starts transporting container 12 to yard block at 6 hours and 36 minutes
# Truck returns to quay crane at 6 hours and 42 minutes
# Vessel 1: Crane starts unloading container 13 at 6 hours and 42 minutes
# Vessel 1: Crane places container 13 on truck at 6 hours and 45 minutes
# Truck starts transporting container 13 to yard block at 6 hours and 45 minutes
# Truck returns to quay crane at 6 hours and 51 minutes
# Vessel 1: Crane starts unloading container 14 at 6 hours and 51 minutes
# Vessel 1: Crane places container 14 on truck at 6 hours and 54 minutes
# Truck starts transporting container 14 to yard block at 6 hours and 54 minutes
# Truck returns to quay crane at 7 hours and 0 minutes
# Vessel 1: Crane starts unloading container 15 at 7 hours and 0 minutes
# Vessel 1: Crane places container 15 on truck at 7 hours and 3 minutes
# Truck starts transporting container 15 to yard block at 7 hours and 3 minutes
# Truck returns to quay crane at 7 hours and 9 minutes
# Vessel 1: Crane starts unloading container 16 at 7 hours and 9 minutes
# Vessel 1: Crane places container 16 on truck at 7 hours and 12 minutes
# Truck starts transporting container 16 to yard block at 7 hours and 12 minutes
# Truck returns to quay crane at 7 hours and 18 minutes
# Vessel 1: Crane starts unloading container 17 at 7 hours and 18 minutes
# Vessel 1: Crane places container 17 on truck at 7 hours and 21 minutes
# Truck starts transporting container 17 to yard block at 7 hours and 21 minutes
# Truck returns to quay crane at 7 hours and 27 minutes
# Vessel 1: Crane starts unloading container 18 at 7 hours and 27 minutes
# Vessel 1: Crane places container 18 on truck at 7 hours and 30 minutes
# Truck starts transporting container 18 to yard block at 7 hours and 30 minutes
# Truck returns to quay crane at 7 hours and 36 minutes
# Vessel 1: Crane starts unloading container 19 at 7 hours and 36 minutes
# Vessel 1: Crane places container 19 on truck at 7 hours and 39 minutes
# Truck starts transporting container 19 to yard block at 7 hours and 39 minutes
# Truck returns to quay crane at 7 hours and 45 minutes
# Vessel 1: Crane starts unloading container 20 at 7 hours and 45 minutes
# Vessel 1: Crane places container 20 on truck at 7 hours and 48 minutes
# Truck starts transporting container 20 to yard block at 7 hours and 48 minutes
# Truck returns to quay crane at 7 hours and 54 minutes
# Vessel 1: Crane starts unloading container 21 at 7 hours and 54 minutes
# Vessel 1: Crane places container 21 on truck at 7 hours and 57 minutes
# Truck starts transporting container 21 to yard block at 7 hours and 57 minutes
# Truck returns to quay crane at 8 hours and 3 minutes
# Vessel 1: Crane starts unloading container 22 at 8 hours and 3 minutes
# Vessel 1: Crane places container 22 on truck at 8 hours and 6 minutes
# Truck starts transporting container 22 to yard block at 8 hours and 6 minutes
# Truck returns to quay crane at 8 hours and 12 minutes
# Vessel 1: Crane starts unloading container 23 at 8 hours and 12 minutes
# Vessel 1: Crane places container 23 on truck at 8 hours and 15 minutes
# Truck starts transporting container 23 to yard block at 8 hours and 15 minutes
# Truck returns to quay crane at 8 hours and 21 minutes
# Vessel 1: Crane starts unloading container 24 at 8 hours and 21 minutes
# Vessel 1: Crane places container 24 on truck at 8 hours and 24 minutes
# Truck starts transporting container 24 to yard block at 8 hours and 24 minutes
# Truck returns to quay crane at 8 hours and 30 minutes
# Vessel 1: Crane starts unloading container 25 at 8 hours and 30 minutes
# Vessel 1: Crane places container 25 on truck at 8 hours and 33 minutes
# Truck starts transporting container 25 to yard block at 8 hours and 33 minutes
# Truck returns to quay crane at 8 hours and 39 minutes
# Vessel 1: Crane starts unloading container 26 at 8 hours and 39 minutes
# Vessel 1: Crane places container 26 on truck at 8 hours and 42 minutes
# Truck starts transporting container 26 to yard block at 8 hours and 42 minutes
# Truck returns to quay crane at 8 hours and 48 minutes
# Vessel 1: Crane starts unloading container 27 at 8 hours and 48 minutes
# Vessel 1: Crane places container 27 on truck at 8 hours and 51 minutes
# Truck starts transporting container 27 to yard block at 8 hours and 51 minutes
# Truck returns to quay crane at 8 hours and 57 minutes
# Vessel 1: Crane starts unloading container 28 at 8 hours and 57 minutes
# Vessel 1: Crane places container 28 on truck at 9 hours and 0 minutes
# Truck starts transporting container 28 to yard block at 9 hours and 0 minutes
# Truck returns to quay crane at 9 hours and 6 minutes
# Vessel 1: Crane starts unloading container 29 at 9 hours and 6 minutes
# Vessel 1: Crane places container 29 on truck at 9 hours and 9 minutes
# Truck starts transporting container 29 to yard block at 9 hours and 9 minutes
# Truck returns to quay crane at 9 hours and 15 minutes
# Vessel 1: Crane starts unloading container 30 at 9 hours and 15 minutes
# Vessel 1: Crane places container 30 on truck at 9 hours and 18 minutes
# Truck starts transporting container 30 to yard block at 9 hours and 18 minutes
# Truck returns to quay crane at 9 hours and 24 minutes
# Vessel 1: Crane starts unloading container 31 at 9 hours and 24 minutes
# Vessel 1: Crane places container 31 on truck at 9 hours and 27 minutes
# Truck starts transporting container 31 to yard block at 9 hours and 27 minutes
# Truck returns to quay crane at 9 hours and 33 minutes
# Vessel 1: Crane starts unloading container 32 at 9 hours and 33 minutes
# Vessel 1: Crane places container 32 on truck at 9 hours and 36 minutes
# Truck starts transporting container 32 to yard block at 9 hours and 36 minutes
# Truck returns to quay crane at 9 hours and 42 minutes
# Vessel 1: Crane starts unloading container 33 at 9 hours and 42 minutes
# Vessel 1: Crane places container 33 on truck at 9 hours and 45 minutes
# Truck starts transporting container 33 to yard block at 9 hours and 45 minutes
# Truck returns to quay crane at 9 hours and 51 minutes
# Vessel 1: Crane starts unloading container 34 at 9 hours and 51 minutes
# Vessel 1: Crane places container 34 on truck at 9 hours and 54 minutes
# Truck starts transporting container 34 to yard block at 9 hours and 54 minutes
# Truck returns to quay crane at 10 hours and 0 minutes
# Vessel 1: Crane starts unloading container 35 at 10 hours and 0 minutes
# Vessel 1: Crane places container 35 on truck at 10 hours and 3 minutes
# Truck starts transporting container 35 to yard block at 10 hours and 3 minutes
# Truck returns to quay crane at 10 hours and 9 minutes
# Vessel 1: Crane starts unloading container 36 at 10 hours and 9 minutes
# Vessel 1: Crane places container 36 on truck at 10 hours and 12 minutes
# Truck starts transporting container 36 to yard block at 10 hours and 12 minutes
# Truck returns to quay crane at 10 hours and 18 minutes
# Vessel 1: Crane starts unloading container 37 at 10 hours and 18 minutes
# Vessel 1: Crane places container 37 on truck at 10 hours and 21 minutes
# Truck starts transporting container 37 to yard block at 10 hours and 21 minutes
# Truck returns to quay crane at 10 hours and 27 minutes
# Vessel 1: Crane starts unloading container 38 at 10 hours and 27 minutes
# Vessel 1: Crane places container 38 on truck at 10 hours and 30 minutes
# Truck starts transporting container 38 to yard block at 10 hours and 30 minutes
# Truck returns to quay crane at 10 hours and 36 minutes
# Vessel 1: Crane starts unloading container 39 at 10 hours and 36 minutes
# Vessel 1: Crane places container 39 on truck at 10 hours and 39 minutes
# Truck starts transporting container 39 to yard block at 10 hours and 39 minutes
# Truck returns to quay crane at 10 hours and 45 minutes
# Vessel 1: Crane starts unloading container 40 at 10 hours and 45 minutes
# Vessel 1: Crane places container 40 on truck at 10 hours and 48 minutes
# Truck starts transporting container 40 to yard block at 10 hours and 48 minutes
# Truck returns to quay crane at 10 hours and 54 minutes
# Vessel 1: Crane starts unloading container 41 at 10 hours and 54 minutes
# Vessel 1: Crane places container 41 on truck at 10 hours and 57 minutes
# Truck starts transporting container 41 to yard block at 10 hours and 57 minutes
# Truck returns to quay crane at 11 hours and 3 minutes
# Vessel 1: Crane starts unloading container 42 at 11 hours and 3 minutes
# Vessel 1: Crane places container 42 on truck at 11 hours and 6 minutes
# Truck starts transporting container 42 to yard block at 11 hours and 6 minutes
# Truck returns to quay crane at 11 hours and 12 minutes
# Vessel 1: Crane starts unloading container 43 at 11 hours and 12 minutes
# Vessel 1: Crane places container 43 on truck at 11 hours and 15 minutes
# Truck starts transporting container 43 to yard block at 11 hours and 15 minutes
# Truck returns to quay crane at 11 hours and 21 minutes
# Vessel 1: Crane starts unloading container 44 at 11 hours and 21 minutes
# Vessel 1: Crane places container 44 on truck at 11 hours and 24 minutes
# Truck starts transporting container 44 to yard block at 11 hours and 24 minutes
# Truck returns to quay crane at 11 hours and 30 minutes
# Vessel 1: Crane starts unloading container 45 at 11 hours and 30 minutes
# Vessel 1: Crane places container 45 on truck at 11 hours and 33 minutes
# Truck starts transporting container 45 to yard block at 11 hours and 33 minutes
# Truck returns to quay crane at 11 hours and 39 minutes
# Vessel 1: Crane starts unloading container 46 at 11 hours and 39 minutes
# Vessel 1: Crane places container 46 on truck at 11 hours and 42 minutes
# Truck starts transporting container 46 to yard block at 11 hours and 42 minutes
# Truck returns to quay crane at 11 hours and 48 minutes
# Vessel 1: Crane starts unloading container 47 at 11 hours and 48 minutes
# Vessel 1: Crane places container 47 on truck at 11 hours and 51 minutes
# Truck starts transporting container 47 to yard block at 11 hours and 51 minutes
# Truck returns to quay crane at 11 hours and 57 minutes
# Vessel 1: Crane starts unloading container 48 at 11 hours and 57 minutes
# Vessel 1: Crane places container 48 on truck at 12 hours and 0 minutes
# Truck starts transporting container 48 to yard block at 12 hours and 0 minutes
# Truck returns to quay crane at 12 hours and 6 minutes
# Vessel 1: Crane starts unloading container 49 at 12 hours and 6 minutes
# Vessel 1: Crane places container 49 on truck at 12 hours and 9 minutes
# Truck starts transporting container 49 to yard block at 12 hours and 9 minutes
# Truck returns to quay crane at 12 hours and 15 minutes
# Vessel 1: Crane starts unloading container 50 at 12 hours and 15 minutes
# Vessel 1: Crane places container 50 on truck at 12 hours and 18 minutes
# Truck starts transporting container 50 to yard block at 12 hours and 18 minutes
# Truck returns to quay crane at 12 hours and 24 minutes
# Vessel 1: Crane starts unloading container 51 at 12 hours and 24 minutes
# Vessel 1: Crane places container 51 on truck at 12 hours and 27 minutes
# Truck starts transporting container 51 to yard block at 12 hours and 27 minutes
# Truck returns to quay crane at 12 hours and 33 minutes
# Vessel 1: Crane starts unloading container 52 at 12 hours and 33 minutes
# Vessel 1: Crane places container 52 on truck at 12 hours and 36 minutes
# Truck starts transporting container 52 to yard block at 12 hours and 36 minutes
# Truck returns to quay crane at 12 hours and 42 minutes
# Vessel 1: Crane starts unloading container 53 at 12 hours and 42 minutes
# Vessel 1: Crane places container 53 on truck at 12 hours and 45 minutes
# Truck starts transporting container 53 to yard block at 12 hours and 45 minutes
# Truck returns to quay crane at 12 hours and 51 minutes
# Vessel 1: Crane starts unloading container 54 at 12 hours and 51 minutes
# Vessel 1: Crane places container 54 on truck at 12 hours and 54 minutes
# Truck starts transporting container 54 to yard block at 12 hours and 54 minutes
# Truck returns to quay crane at 13 hours and 0 minutes
# Vessel 1: Crane starts unloading container 55 at 13 hours and 0 minutes
# Vessel 1: Crane places container 55 on truck at 13 hours and 3 minutes
# Truck starts transporting container 55 to yard block at 13 hours and 3 minutes
# Truck returns to quay crane at 13 hours and 9 minutes
# Vessel 1: Crane starts unloading container 56 at 13 hours and 9 minutes
# Vessel 1: Crane places container 56 on truck at 13 hours and 12 minutes
# Truck starts transporting container 56 to yard block at 13 hours and 12 minutes
# Truck returns to quay crane at 13 hours and 18 minutes
# Vessel 1: Crane starts unloading container 57 at 13 hours and 18 minutes
# Vessel 1: Crane places container 57 on truck at 13 hours and 21 minutes
# Truck starts transporting container 57 to yard block at 13 hours and 21 minutes
# Truck returns to quay crane at 13 hours and 27 minutes
# Vessel 1: Crane starts unloading container 58 at 13 hours and 27 minutes
# Vessel 1: Crane places container 58 on truck at 13 hours and 30 minutes
# Truck starts transporting container 58 to yard block at 13 hours and 30 minutes
# Truck returns to quay crane at 13 hours and 36 minutes
# Vessel 1: Crane starts unloading container 59 at 13 hours and 36 minutes
# Vessel 1: Crane places container 59 on truck at 13 hours and 39 minutes
# Truck starts transporting container 59 to yard block at 13 hours and 39 minutes
# Truck returns to quay crane at 13 hours and 45 minutes
# Vessel 1: Crane starts unloading container 60 at 13 hours and 45 minutes
# Vessel 1: Crane places container 60 on truck at 13 hours and 48 minutes
# Truck starts transporting container 60 to yard block at 13 hours and 48 minutes
# Truck returns to quay crane at 13 hours and 54 minutes
# Vessel 1: Crane starts unloading container 61 at 13 hours and 54 minutes
# Vessel 1: Crane places container 61 on truck at 13 hours and 57 minutes
# Truck starts transporting container 61 to yard block at 13 hours and 57 minutes
# Truck returns to quay crane at 14 hours and 3 minutes
# Vessel 1: Crane starts unloading container 62 at 14 hours and 3 minutes
# Vessel 1: Crane places container 62 on truck at 14 hours and 6 minutes
# Truck starts transporting container 62 to yard block at 14 hours and 6 minutes
# Truck returns to quay crane at 14 hours and 12 minutes
# Vessel 1: Crane starts unloading container 63 at 14 hours and 12 minutes
# Vessel 1: Crane places container 63 on truck at 14 hours and 15 minutes
# Truck starts transporting container 63 to yard block at 14 hours and 15 minutes
# Truck returns to quay crane at 14 hours and 21 minutes
# Vessel 1: Crane starts unloading container 64 at 14 hours and 21 minutes
# Vessel 1: Crane places container 64 on truck at 14 hours and 24 minutes
# Truck starts transporting container 64 to yard block at 14 hours and 24 minutes
# Truck returns to quay crane at 14 hours and 30 minutes
# Vessel 1: Crane starts unloading container 65 at 14 hours and 30 minutes
# Vessel 1: Crane places container 65 on truck at 14 hours and 33 minutes
# Truck starts transporting container 65 to yard block at 14 hours and 33 minutes
# Truck returns to quay crane at 14 hours and 39 minutes
# Vessel 1: Crane starts unloading container 66 at 14 hours and 39 minutes
# Vessel 1: Crane places container 66 on truck at 14 hours and 42 minutes
# Truck starts transporting container 66 to yard block at 14 hours and 42 minutes
# Vessel 2 (Priority 1) arrives at 14 hours and 46 minutes
# Vessel 2 berths at 14 hours and 46 minutes after waiting for 0 hours and 0 minutes
# Vessel 2: Crane starts unloading container 1 at 14 hours and 46 minutes
# Truck returns to quay crane at 14 hours and 48 minutes
# Vessel 1: Crane starts unloading container 67 at 14 hours and 48 minutes
# Vessel 2: Crane places container 1 on truck at 14 hours and 49 minutes
# Truck starts transporting container 1 to yard block at 14 hours and 49 minutes
# Vessel 1: Crane places container 67 on truck at 14 hours and 51 minutes
# Truck starts transporting container 67 to yard block at 14 hours and 51 minutes
# Truck returns to quay crane at 14 hours and 55 minutes
# Vessel 2: Crane starts unloading container 2 at 14 hours and 55 minutes
# Truck returns to quay crane at 14 hours and 57 minutes
# Vessel 1: Crane starts unloading container 68 at 14 hours and 57 minutes
# Vessel 2: Crane places container 2 on truck at 14 hours and 58 minutes
# Truck starts transporting container 2 to yard block at 14 hours and 58 minutes
# Vessel 1: Crane places container 68 on truck at 15 hours and 0 minutes
# Truck starts transporting container 68 to yard block at 15 hours and 0 minutes
# Truck returns to quay crane at 15 hours and 4 minutes
# Vessel 2: Crane starts unloading container 3 at 15 hours and 4 minutes
# Truck returns to quay crane at 15 hours and 6 minutes
# Vessel 1: Crane starts unloading container 69 at 15 hours and 6 minutes
# Vessel 2: Crane places container 3 on truck at 15 hours and 7 minutes
# Truck starts transporting container 3 to yard block at 15 hours and 7 minutes
# Vessel 1: Crane places container 69 on truck at 15 hours and 9 minutes
# Truck starts transporting container 69 to yard block at 15 hours and 9 minutes
# Truck returns to quay crane at 15 hours and 13 minutes
# Vessel 2: Crane starts unloading container 4 at 15 hours and 13 minutes
# Truck returns to quay crane at 15 hours and 15 minutes
# Vessel 1: Crane starts unloading container 70 at 15 hours and 15 minutes
# Vessel 2: Crane places container 4 on truck at 15 hours and 16 minutes
# Truck starts transporting container 4 to yard block at 15 hours and 16 minutes
# Vessel 1: Crane places container 70 on truck at 15 hours and 18 minutes
# Truck starts transporting container 70 to yard block at 15 hours and 18 minutes
# Truck returns to quay crane at 15 hours and 22 minutes
# Vessel 2: Crane starts unloading container 5 at 15 hours and 22 minutes
# Truck returns to quay crane at 15 hours and 24 minutes
# Vessel 1: Crane starts unloading container 71 at 15 hours and 24 minutes
# Vessel 2: Crane places container 5 on truck at 15 hours and 25 minutes
# Truck starts transporting container 5 to yard block at 15 hours and 25 minutes
# Vessel 1: Crane places container 71 on truck at 15 hours and 27 minutes
# Truck starts transporting container 71 to yard block at 15 hours and 27 minutes
# Truck returns to quay crane at 15 hours and 31 minutes
# Vessel 2: Crane starts unloading container 6 at 15 hours and 31 minutes
# Truck returns to quay crane at 15 hours and 33 minutes
# Vessel 1: Crane starts unloading container 72 at 15 hours and 33 minutes
# Vessel 2: Crane places container 6 on truck at 15 hours and 34 minutes
# Truck starts transporting container 6 to yard block at 15 hours and 34 minutes
# Vessel 1: Crane places container 72 on truck at 15 hours and 36 minutes
# Truck starts transporting container 72 to yard block at 15 hours and 36 minutes
# Truck returns to quay crane at 15 hours and 40 minutes
# Vessel 2: Crane starts unloading container 7 at 15 hours and 40 minutes
# Truck returns to quay crane at 15 hours and 42 minutes
# Vessel 1: Crane starts unloading container 73 at 15 hours and 42 minutes
# Vessel 2: Crane places container 7 on truck at 15 hours and 43 minutes
# Truck starts transporting container 7 to yard block at 15 hours and 43 minutes
# Vessel 1: Crane places container 73 on truck at 15 hours and 45 minutes
# Truck starts transporting container 73 to yard block at 15 hours and 45 minutes
# Truck returns to quay crane at 15 hours and 49 minutes
# Vessel 2: Crane starts unloading container 8 at 15 hours and 49 minutes
# Truck returns to quay crane at 15 hours and 51 minutes
# Vessel 1: Crane starts unloading container 74 at 15 hours and 51 minutes
# Vessel 2: Crane places container 8 on truck at 15 hours and 52 minutes
# Truck starts transporting container 8 to yard block at 15 hours and 52 minutes
# Vessel 1: Crane places container 74 on truck at 15 hours and 54 minutes
# Truck starts transporting container 74 to yard block at 15 hours and 54 minutes
# Truck returns to quay crane at 15 hours and 58 minutes
# Vessel 2: Crane starts unloading container 9 at 15 hours and 58 minutes
# Truck returns to quay crane at 16 hours and 0 minutes
# Vessel 1: Crane starts unloading container 75 at 16 hours and 0 minutes
# Vessel 2: Crane places container 9 on truck at 16 hours and 1 minutes
# Truck starts transporting container 9 to yard block at 16 hours and 1 minutes
# Vessel 1: Crane places container 75 on truck at 16 hours and 3 minutes
# Truck starts transporting container 75 to yard block at 16 hours and 3 minutes
# Truck returns to quay crane at 16 hours and 7 minutes
# Vessel 2: Crane starts unloading container 10 at 16 hours and 7 minutes
# Truck returns to quay crane at 16 hours and 9 minutes
# Vessel 1: Crane starts unloading container 76 at 16 hours and 9 minutes
# Vessel 2: Crane places container 10 on truck at 16 hours and 10 minutes
# Truck starts transporting container 10 to yard block at 16 hours and 10 minutes
# Vessel 1: Crane places container 76 on truck at 16 hours and 12 minutes
# Truck starts transporting container 76 to yard block at 16 hours and 12 minutes
# Truck returns to quay crane at 16 hours and 16 minutes
# Vessel 2: Crane starts unloading container 11 at 16 hours and 16 minutes
# Truck returns to quay crane at 16 hours and 18 minutes
# Vessel 1: Crane starts unloading container 77 at 16 hours and 18 minutes
# Vessel 2: Crane places container 11 on truck at 16 hours and 19 minutes
# Truck starts transporting container 11 to yard block at 16 hours and 19 minutes
# Vessel 1: Crane places container 77 on truck at 16 hours and 21 minutes
# Truck starts transporting container 77 to yard block at 16 hours and 21 minutes
# Truck returns to quay crane at 16 hours and 25 minutes
# Vessel 2: Crane starts unloading container 12 at 16 hours and 25 minutes
# Truck returns to quay crane at 16 hours and 27 minutes
# Vessel 1: Crane starts unloading container 78 at 16 hours and 27 minutes
# Vessel 2: Crane places container 12 on truck at 16 hours and 28 minutes
# Truck starts transporting container 12 to yard block at 16 hours and 28 minutes
# Vessel 1: Crane places container 78 on truck at 16 hours and 30 minutes
# Truck starts transporting container 78 to yard block at 16 hours and 30 minutes
# Truck returns to quay crane at 16 hours and 34 minutes
# Vessel 2: Crane starts unloading container 13 at 16 hours and 34 minutes
# Truck returns to quay crane at 16 hours and 36 minutes
# Vessel 1: Crane starts unloading container 79 at 16 hours and 36 minutes
# Vessel 2: Crane places container 13 on truck at 16 hours and 37 minutes
# Truck starts transporting container 13 to yard block at 16 hours and 37 minutes
# Vessel 1: Crane places container 79 on truck at 16 hours and 39 minutes
# Truck starts transporting container 79 to yard block at 16 hours and 39 minutes
# Truck returns to quay crane at 16 hours and 43 minutes
# Vessel 2: Crane starts unloading container 14 at 16 hours and 43 minutes
# Truck returns to quay crane at 16 hours and 45 minutes
# Vessel 1: Crane starts unloading container 80 at 16 hours and 45 minutes
# Vessel 2: Crane places container 14 on truck at 16 hours and 46 minutes
# Truck starts transporting container 14 to yard block at 16 hours and 46 minutes
# Vessel 1: Crane places container 80 on truck at 16 hours and 48 minutes
# Truck starts transporting container 80 to yard block at 16 hours and 48 minutes
# Truck returns to quay crane at 16 hours and 52 minutes
# Vessel 2: Crane starts unloading container 15 at 16 hours and 52 minutes
# Truck returns to quay crane at 16 hours and 54 minutes
# Vessel 1: Crane starts unloading container 81 at 16 hours and 54 minutes
# Vessel 2: Crane places container 15 on truck at 16 hours and 55 minutes
# Truck starts transporting container 15 to yard block at 16 hours and 55 minutes
# Vessel 1: Crane places container 81 on truck at 16 hours and 57 minutes
# Truck starts transporting container 81 to yard block at 16 hours and 57 minutes
# Truck returns to quay crane at 17 hours and 1 minutes
# Vessel 2: Crane starts unloading container 16 at 17 hours and 1 minutes
# Truck returns to quay crane at 17 hours and 3 minutes
# Vessel 1: Crane starts unloading container 82 at 17 hours and 3 minutes
# Vessel 2: Crane places container 16 on truck at 17 hours and 4 minutes
# Truck starts transporting container 16 to yard block at 17 hours and 4 minutes
# Vessel 1: Crane places container 82 on truck at 17 hours and 6 minutes
# Truck starts transporting container 82 to yard block at 17 hours and 6 minutes
# Truck returns to quay crane at 17 hours and 10 minutes
# Vessel 2: Crane starts unloading container 17 at 17 hours and 10 minutes
# Truck returns to quay crane at 17 hours and 12 minutes
# Vessel 1: Crane starts unloading container 83 at 17 hours and 12 minutes
# Vessel 2: Crane places container 17 on truck at 17 hours and 13 minutes
# Truck starts transporting container 17 to yard block at 17 hours and 13 minutes
# Vessel 1: Crane places container 83 on truck at 17 hours and 15 minutes
# Truck starts transporting container 83 to yard block at 17 hours and 15 minutes
# Truck returns to quay crane at 17 hours and 19 minutes
# Vessel 2: Crane starts unloading container 18 at 17 hours and 19 minutes
# Truck returns to quay crane at 17 hours and 21 minutes
# Vessel 1: Crane starts unloading container 84 at 17 hours and 21 minutes
# Vessel 2: Crane places container 18 on truck at 17 hours and 22 minutes
# Truck starts transporting container 18 to yard block at 17 hours and 22 minutes
# Vessel 1: Crane places container 84 on truck at 17 hours and 24 minutes
# Truck starts transporting container 84 to yard block at 17 hours and 24 minutes
# Truck returns to quay crane at 17 hours and 28 minutes
# Vessel 2: Crane starts unloading container 19 at 17 hours and 28 minutes
# Truck returns to quay crane at 17 hours and 30 minutes
# Vessel 1: Crane starts unloading container 85 at 17 hours and 30 minutes
# Vessel 2: Crane places container 19 on truck at 17 hours and 31 minutes
# Truck starts transporting container 19 to yard block at 17 hours and 31 minutes
# Vessel 1: Crane places container 85 on truck at 17 hours and 33 minutes
# Truck starts transporting container 85 to yard block at 17 hours and 33 minutes
# Truck returns to quay crane at 17 hours and 37 minutes
# Vessel 2: Crane starts unloading container 20 at 17 hours and 37 minutes
# Truck returns to quay crane at 17 hours and 39 minutes
# Vessel 1: Crane starts unloading container 86 at 17 hours and 39 minutes
# Vessel 2: Crane places container 20 on truck at 17 hours and 40 minutes
# Truck starts transporting container 20 to yard block at 17 hours and 40 minutes
# Vessel 1: Crane places container 86 on truck at 17 hours and 42 minutes
# Truck starts transporting container 86 to yard block at 17 hours and 42 minutes
# Truck returns to quay crane at 17 hours and 46 minutes
# Vessel 2: Crane starts unloading container 21 at 17 hours and 46 minutes
# Truck returns to quay crane at 17 hours and 48 minutes
# Vessel 1: Crane starts unloading container 87 at 17 hours and 48 minutes
# Vessel 2: Crane places container 21 on truck at 17 hours and 49 minutes
# Truck starts transporting container 21 to yard block at 17 hours and 49 minutes
# Vessel 3 (Priority 1) arrives at 17 hours and 49 minutes
# Vessel 1: Crane places container 87 on truck at 17 hours and 51 minutes
# Truck starts transporting container 87 to yard block at 17 hours and 51 minutes
# Truck returns to quay crane at 17 hours and 55 minutes
# Vessel 2: Crane starts unloading container 22 at 17 hours and 55 minutes
# Truck returns to quay crane at 17 hours and 57 minutes
# Vessel 1: Crane starts unloading container 88 at 17 hours and 57 minutes
# Vessel 2: Crane places container 22 on truck at 17 hours and 58 minutes
# Truck starts transporting container 22 to yard block at 17 hours and 58 minutes
# Vessel 1: Crane places container 88 on truck at 18 hours and 0 minutes
# Truck starts transporting container 88 to yard block at 18 hours and 0 minutes
# Truck returns to quay crane at 18 hours and 4 minutes
# Vessel 2: Crane starts unloading container 23 at 18 hours and 4 minutes
# Truck returns to quay crane at 18 hours and 6 minutes
# Vessel 1: Crane starts unloading container 89 at 18 hours and 6 minutes
# Vessel 2: Crane places container 23 on truck at 18 hours and 7 minutes
# Truck starts transporting container 23 to yard block at 18 hours and 7 minutes
# Vessel 1: Crane places container 89 on truck at 18 hours and 9 minutes
# Truck starts transporting container 89 to yard block at 18 hours and 9 minutes
# Truck returns to quay crane at 18 hours and 13 minutes
# Vessel 2: Crane starts unloading container 24 at 18 hours and 13 minutes
# Truck returns to quay crane at 18 hours and 15 minutes
# Vessel 1: Crane starts unloading container 90 at 18 hours and 15 minutes
# Vessel 2: Crane places container 24 on truck at 18 hours and 16 minutes
# Truck starts transporting container 24 to yard block at 18 hours and 16 minutes
# Vessel 1: Crane places container 90 on truck at 18 hours and 18 minutes
# Truck starts transporting container 90 to yard block at 18 hours and 18 minutes
# Truck returns to quay crane at 18 hours and 22 minutes
# Vessel 2: Crane starts unloading container 25 at 18 hours and 22 minutes
# Truck returns to quay crane at 18 hours and 24 minutes
# Vessel 1: Crane starts unloading container 91 at 18 hours and 24 minutes
# Vessel 2: Crane places container 25 on truck at 18 hours and 25 minutes
# Truck starts transporting container 25 to yard block at 18 hours and 25 minutes
# Vessel 1: Crane places container 91 on truck at 18 hours and 27 minutes
# Truck starts transporting container 91 to yard block at 18 hours and 27 minutes
# Truck returns to quay crane at 18 hours and 31 minutes
# Vessel 2: Crane starts unloading container 26 at 18 hours and 31 minutes
# Truck returns to quay crane at 18 hours and 33 minutes
# Vessel 1: Crane starts unloading container 92 at 18 hours and 33 minutes
# Vessel 2: Crane places container 26 on truck at 18 hours and 34 minutes
# Truck starts transporting container 26 to yard block at 18 hours and 34 minutes
# Vessel 1: Crane places container 92 on truck at 18 hours and 36 minutes
# Truck starts transporting container 92 to yard block at 18 hours and 36 minutes
# Truck returns to quay crane at 18 hours and 40 minutes
# Vessel 2: Crane starts unloading container 27 at 18 hours and 40 minutes
# Truck returns to quay crane at 18 hours and 42 minutes
# Vessel 1: Crane starts unloading container 93 at 18 hours and 42 minutes
# Vessel 2: Crane places container 27 on truck at 18 hours and 43 minutes
# Truck starts transporting container 27 to yard block at 18 hours and 43 minutes
# Vessel 1: Crane places container 93 on truck at 18 hours and 45 minutes
# Truck starts transporting container 93 to yard block at 18 hours and 45 minutes
# Truck returns to quay crane at 18 hours and 49 minutes
# Vessel 2: Crane starts unloading container 28 at 18 hours and 49 minutes
# Truck returns to quay crane at 18 hours and 51 minutes
# Vessel 1: Crane starts unloading container 94 at 18 hours and 51 minutes
# Vessel 2: Crane places container 28 on truck at 18 hours and 52 minutes
# Truck starts transporting container 28 to yard block at 18 hours and 52 minutes
# Vessel 1: Crane places container 94 on truck at 18 hours and 54 minutes
# Truck starts transporting container 94 to yard block at 18 hours and 54 minutes
# Vessel 4 (Priority 2) arrives at 18 hours and 57 minutes
# Truck returns to quay crane at 18 hours and 58 minutes
# Vessel 2: Crane starts unloading container 29 at 18 hours and 58 minutes
# Truck returns to quay crane at 19 hours and 0 minutes
# Vessel 1: Crane starts unloading container 95 at 19 hours and 0 minutes
# Vessel 2: Crane places container 29 on truck at 19 hours and 1 minutes
# Truck starts transporting container 29 to yard block at 19 hours and 1 minutes
# Vessel 1: Crane places container 95 on truck at 19 hours and 3 minutes
# Truck starts transporting container 95 to yard block at 19 hours and 3 minutes
# Truck returns to quay crane at 19 hours and 7 minutes
# Vessel 2: Crane starts unloading container 30 at 19 hours and 7 minutes
# Truck returns to quay crane at 19 hours and 9 minutes
# Vessel 1: Crane starts unloading container 96 at 19 hours and 9 minutes
# Vessel 2: Crane places container 30 on truck at 19 hours and 10 minutes
# Truck starts transporting container 30 to yard block at 19 hours and 10 minutes
# Vessel 1: Crane places container 96 on truck at 19 hours and 12 minutes
# Truck starts transporting container 96 to yard block at 19 hours and 12 minutes
# Truck returns to quay crane at 19 hours and 16 minutes
# Vessel 2: Crane starts unloading container 31 at 19 hours and 16 minutes
# Truck returns to quay crane at 19 hours and 18 minutes
# Vessel 1: Crane starts unloading container 97 at 19 hours and 18 minutes
# Vessel 2: Crane places container 31 on truck at 19 hours and 19 minutes
# Truck starts transporting container 31 to yard block at 19 hours and 19 minutes
# Vessel 1: Crane places container 97 on truck at 19 hours and 21 minutes
# Truck starts transporting container 97 to yard block at 19 hours and 21 minutes
# Truck returns to quay crane at 19 hours and 25 minutes
# Vessel 2: Crane starts unloading container 32 at 19 hours and 25 minutes
# Truck returns to quay crane at 19 hours and 27 minutes
# Vessel 1: Crane starts unloading container 98 at 19 hours and 27 minutes
# Vessel 2: Crane places container 32 on truck at 19 hours and 28 minutes
# Truck starts transporting container 32 to yard block at 19 hours and 28 minutes
# Vessel 1: Crane places container 98 on truck at 19 hours and 30 minutes
# Truck starts transporting container 98 to yard block at 19 hours and 30 minutes
# Truck returns to quay crane at 19 hours and 34 minutes
# Vessel 2: Crane starts unloading container 33 at 19 hours and 34 minutes
# Truck returns to quay crane at 19 hours and 36 minutes
# Vessel 1: Crane starts unloading container 99 at 19 hours and 36 minutes
# Vessel 2: Crane places container 33 on truck at 19 hours and 37 minutes
# Truck starts transporting container 33 to yard block at 19 hours and 37 minutes
# Vessel 1: Crane places container 99 on truck at 19 hours and 39 minutes
# Truck starts transporting container 99 to yard block at 19 hours and 39 minutes
# Truck returns to quay crane at 19 hours and 43 minutes
# Vessel 2: Crane starts unloading container 34 at 19 hours and 43 minutes
# Truck returns to quay crane at 19 hours and 45 minutes
# Vessel 1: Crane starts unloading container 100 at 19 hours and 45 minutes
# Vessel 2: Crane places container 34 on truck at 19 hours and 46 minutes
# Truck starts transporting container 34 to yard block at 19 hours and 46 minutes
# Vessel 1: Crane places container 100 on truck at 19 hours and 48 minutes
# Truck starts transporting container 100 to yard block at 19 hours and 48 minutes
# Truck returns to quay crane at 19 hours and 52 minutes
# Vessel 2: Crane starts unloading container 35 at 19 hours and 52 minutes
# Truck returns to quay crane at 19 hours and 54 minutes
# Vessel 1: Crane starts unloading container 101 at 19 hours and 54 minutes
# Vessel 2: Crane places container 35 on truck at 19 hours and 55 minutes
# Truck starts transporting container 35 to yard block at 19 hours and 55 minutes
# Vessel 1: Crane places container 101 on truck at 19 hours and 57 minutes
# Truck starts transporting container 101 to yard block at 19 hours and 57 minutes
# Truck returns to quay crane at 20 hours and 1 minutes
# Vessel 2: Crane starts unloading container 36 at 20 hours and 1 minutes
# Truck returns to quay crane at 20 hours and 3 minutes
# Vessel 1: Crane starts unloading container 102 at 20 hours and 3 minutes
# Vessel 2: Crane places container 36 on truck at 20 hours and 4 minutes
# Truck starts transporting container 36 to yard block at 20 hours and 4 minutes
# Vessel 1: Crane places container 102 on truck at 20 hours and 6 minutes
# Truck starts transporting container 102 to yard block at 20 hours and 6 minutes
# Truck returns to quay crane at 20 hours and 10 minutes
# Vessel 2: Crane starts unloading container 37 at 20 hours and 10 minutes
# Truck returns to quay crane at 20 hours and 12 minutes
# Vessel 1: Crane starts unloading container 103 at 20 hours and 12 minutes
# Vessel 2: Crane places container 37 on truck at 20 hours and 13 minutes
# Truck starts transporting container 37 to yard block at 20 hours and 13 minutes
# Vessel 1: Crane places container 103 on truck at 20 hours and 15 minutes
# Truck starts transporting container 103 to yard block at 20 hours and 15 minutes
# Truck returns to quay crane at 20 hours and 19 minutes
# Vessel 2: Crane starts unloading container 38 at 20 hours and 19 minutes
# Truck returns to quay crane at 20 hours and 21 minutes
# Vessel 1: Crane starts unloading container 104 at 20 hours and 21 minutes
# Vessel 2: Crane places container 38 on truck at 20 hours and 22 minutes
# Truck starts transporting container 38 to yard block at 20 hours and 22 minutes
# Vessel 1: Crane places container 104 on truck at 20 hours and 24 minutes
# Truck starts transporting container 104 to yard block at 20 hours and 24 minutes
# Truck returns to quay crane at 20 hours and 28 minutes
# Vessel 2: Crane starts unloading container 39 at 20 hours and 28 minutes
# Truck returns to quay crane at 20 hours and 30 minutes
# Vessel 1: Crane starts unloading container 105 at 20 hours and 30 minutes
# Vessel 2: Crane places container 39 on truck at 20 hours and 31 minutes
# Truck starts transporting container 39 to yard block at 20 hours and 31 minutes
# Vessel 1: Crane places container 105 on truck at 20 hours and 33 minutes
# Truck starts transporting container 105 to yard block at 20 hours and 33 minutes
# Truck returns to quay crane at 20 hours and 37 minutes
# Vessel 2: Crane starts unloading container 40 at 20 hours and 37 minutes
# Truck returns to quay crane at 20 hours and 39 minutes
# Vessel 1: Crane starts unloading container 106 at 20 hours and 39 minutes
# Vessel 2: Crane places container 40 on truck at 20 hours and 40 minutes
# Truck starts transporting container 40 to yard block at 20 hours and 40 minutes
# Vessel 1: Crane places container 106 on truck at 20 hours and 42 minutes
# Truck starts transporting container 106 to yard block at 20 hours and 42 minutes
# Truck returns to quay crane at 20 hours and 46 minutes
# Vessel 2: Crane starts unloading container 41 at 20 hours and 46 minutes
# Truck returns to quay crane at 20 hours and 48 minutes
# Vessel 1: Crane starts unloading container 107 at 20 hours and 48 minutes
# Vessel 2: Crane places container 41 on truck at 20 hours and 49 minutes
# Truck starts transporting container 41 to yard block at 20 hours and 49 minutes
# Vessel 1: Crane places container 107 on truck at 20 hours and 51 minutes
# Truck starts transporting container 107 to yard block at 20 hours and 51 minutes
# Truck returns to quay crane at 20 hours and 55 minutes
# Vessel 2: Crane starts unloading container 42 at 20 hours and 55 minutes
# Truck returns to quay crane at 20 hours and 57 minutes
# Vessel 1: Crane starts unloading container 108 at 20 hours and 57 minutes
# Vessel 2: Crane places container 42 on truck at 20 hours and 58 minutes
# Truck starts transporting container 42 to yard block at 20 hours and 58 minutes
# Vessel 1: Crane places container 108 on truck at 21 hours and 0 minutes
# Truck starts transporting container 108 to yard block at 21 hours and 0 minutes
# Truck returns to quay crane at 21 hours and 4 minutes
# Vessel 2: Crane starts unloading container 43 at 21 hours and 4 minutes
# Truck returns to quay crane at 21 hours and 6 minutes
# Vessel 1: Crane starts unloading container 109 at 21 hours and 6 minutes
# Vessel 2: Crane places container 43 on truck at 21 hours and 7 minutes
# Truck starts transporting container 43 to yard block at 21 hours and 7 minutes
# Vessel 1: Crane places container 109 on truck at 21 hours and 9 minutes
# Truck starts transporting container 109 to yard block at 21 hours and 9 minutes
# Truck returns to quay crane at 21 hours and 13 minutes
# Vessel 2: Crane starts unloading container 44 at 21 hours and 13 minutes
# Truck returns to quay crane at 21 hours and 15 minutes
# Vessel 1: Crane starts unloading container 110 at 21 hours and 15 minutes
# Vessel 2: Crane places container 44 on truck at 21 hours and 16 minutes
# Truck starts transporting container 44 to yard block at 21 hours and 16 minutes
# Vessel 1: Crane places container 110 on truck at 21 hours and 18 minutes
# Truck starts transporting container 110 to yard block at 21 hours and 18 minutes
# Truck returns to quay crane at 21 hours and 22 minutes
# Vessel 2: Crane starts unloading container 45 at 21 hours and 22 minutes
# Truck returns to quay crane at 21 hours and 24 minutes
# Vessel 1: Crane starts unloading container 111 at 21 hours and 24 minutes
# Vessel 2: Crane places container 45 on truck at 21 hours and 25 minutes
# Truck starts transporting container 45 to yard block at 21 hours and 25 minutes
# Vessel 1: Crane places container 111 on truck at 21 hours and 27 minutes
# Truck starts transporting container 111 to yard block at 21 hours and 27 minutes
# Truck returns to quay crane at 21 hours and 31 minutes
# Vessel 2: Crane starts unloading container 46 at 21 hours and 31 minutes
# Truck returns to quay crane at 21 hours and 33 minutes
# Vessel 1: Crane starts unloading container 112 at 21 hours and 33 minutes
# Vessel 2: Crane places container 46 on truck at 21 hours and 34 minutes
# Truck starts transporting container 46 to yard block at 21 hours and 34 minutes
# Vessel 1: Crane places container 112 on truck at 21 hours and 36 minutes
# Truck starts transporting container 112 to yard block at 21 hours and 36 minutes
# Truck returns to quay crane at 21 hours and 40 minutes
# Vessel 2: Crane starts unloading container 47 at 21 hours and 40 minutes
# Truck returns to quay crane at 21 hours and 42 minutes
# Vessel 1: Crane starts unloading container 113 at 21 hours and 42 minutes
# Vessel 2: Crane places container 47 on truck at 21 hours and 43 minutes
# Truck starts transporting container 47 to yard block at 21 hours and 43 minutes
# Vessel 1: Crane places container 113 on truck at 21 hours and 45 minutes
# Truck starts transporting container 113 to yard block at 21 hours and 45 minutes
# Truck returns to quay crane at 21 hours and 49 minutes
# Vessel 2: Crane starts unloading container 48 at 21 hours and 49 minutes
# Truck returns to quay crane at 21 hours and 51 minutes
# Vessel 1: Crane starts unloading container 114 at 21 hours and 51 minutes
# Vessel 2: Crane places container 48 on truck at 21 hours and 52 minutes
# Truck starts transporting container 48 to yard block at 21 hours and 52 minutes
# Vessel 1: Crane places container 114 on truck at 21 hours and 54 minutes
# Truck starts transporting container 114 to yard block at 21 hours and 54 minutes
# Truck returns to quay crane at 21 hours and 58 minutes
# Vessel 2: Crane starts unloading container 49 at 21 hours and 58 minutes
# Truck returns to quay crane at 22 hours and 0 minutes
# Vessel 1: Crane starts unloading container 115 at 22 hours and 0 minutes
# Vessel 2: Crane places container 49 on truck at 22 hours and 1 minutes
# Truck starts transporting container 49 to yard block at 22 hours and 1 minutes
# Vessel 1: Crane places container 115 on truck at 22 hours and 3 minutes
# Truck starts transporting container 115 to yard block at 22 hours and 3 minutes
# Truck returns to quay crane at 22 hours and 7 minutes
# Vessel 2: Crane starts unloading container 50 at 22 hours and 7 minutes
# Truck returns to quay crane at 22 hours and 9 minutes
# Vessel 1: Crane starts unloading container 116 at 22 hours and 9 minutes
# Vessel 2: Crane places container 50 on truck at 22 hours and 10 minutes
# Truck starts transporting container 50 to yard block at 22 hours and 10 minutes
# Vessel 1: Crane places container 116 on truck at 22 hours and 12 minutes
# Truck starts transporting container 116 to yard block at 22 hours and 12 minutes
# Truck returns to quay crane at 22 hours and 16 minutes
# Vessel 2: Crane starts unloading container 51 at 22 hours and 16 minutes
# Truck returns to quay crane at 22 hours and 18 minutes
# Vessel 1: Crane starts unloading container 117 at 22 hours and 18 minutes
# Vessel 2: Crane places container 51 on truck at 22 hours and 19 minutes
# Truck starts transporting container 51 to yard block at 22 hours and 19 minutes
# Vessel 1: Crane places container 117 on truck at 22 hours and 21 minutes
# Truck starts transporting container 117 to yard block at 22 hours and 21 minutes
# Truck returns to quay crane at 22 hours and 25 minutes
# Vessel 2: Crane starts unloading container 52 at 22 hours and 25 minutes
# Truck returns to quay crane at 22 hours and 27 minutes
# Vessel 1: Crane starts unloading container 118 at 22 hours and 27 minutes
# Vessel 2: Crane places container 52 on truck at 22 hours and 28 minutes
# Truck starts transporting container 52 to yard block at 22 hours and 28 minutes
# Vessel 1: Crane places container 118 on truck at 22 hours and 30 minutes
# Truck starts transporting container 118 to yard block at 22 hours and 30 minutes
# Truck returns to quay crane at 22 hours and 34 minutes
# Vessel 2: Crane starts unloading container 53 at 22 hours and 34 minutes
# Truck returns to quay crane at 22 hours and 36 minutes
# Vessel 1: Crane starts unloading container 119 at 22 hours and 36 minutes
# Vessel 2: Crane places container 53 on truck at 22 hours and 37 minutes
# Truck starts transporting container 53 to yard block at 22 hours and 37 minutes
# Vessel 1: Crane places container 119 on truck at 22 hours and 39 minutes
# Truck starts transporting container 119 to yard block at 22 hours and 39 minutes
# Truck returns to quay crane at 22 hours and 43 minutes
# Vessel 2: Crane starts unloading container 54 at 22 hours and 43 minutes
# Truck returns to quay crane at 22 hours and 45 minutes
# Vessel 1: Crane starts unloading container 120 at 22 hours and 45 minutes
# Vessel 2: Crane places container 54 on truck at 22 hours and 46 minutes
# Truck starts transporting container 54 to yard block at 22 hours and 46 minutes
# Vessel 1: Crane places container 120 on truck at 22 hours and 48 minutes
# Truck starts transporting container 120 to yard block at 22 hours and 48 minutes
# Truck returns to quay crane at 22 hours and 52 minutes
# Vessel 2: Crane starts unloading container 55 at 22 hours and 52 minutes
# Truck returns to quay crane at 22 hours and 54 minutes
# Vessel 1: Crane starts unloading container 121 at 22 hours and 54 minutes
# Vessel 2: Crane places container 55 on truck at 22 hours and 55 minutes
# Truck starts transporting container 55 to yard block at 22 hours and 55 minutes
# Vessel 1: Crane places container 121 on truck at 22 hours and 57 minutes
# Truck starts transporting container 121 to yard block at 22 hours and 57 minutes
# Truck returns to quay crane at 23 hours and 1 minutes
# Vessel 2: Crane starts unloading container 56 at 23 hours and 1 minutes
# Truck returns to quay crane at 23 hours and 3 minutes
# Vessel 1: Crane starts unloading container 122 at 23 hours and 3 minutes
# Vessel 2: Crane places container 56 on truck at 23 hours and 4 minutes
# Truck starts transporting container 56 to yard block at 23 hours and 4 minutes
# Vessel 1: Crane places container 122 on truck at 23 hours and 6 minutes
# Truck starts transporting container 122 to yard block at 23 hours and 6 minutes
# Truck returns to quay crane at 23 hours and 10 minutes
# Vessel 2: Crane starts unloading container 57 at 23 hours and 10 minutes
# Truck returns to quay crane at 23 hours and 12 minutes
# Vessel 1: Crane starts unloading container 123 at 23 hours and 12 minutes
# Vessel 2: Crane places container 57 on truck at 23 hours and 13 minutes
# Truck starts transporting container 57 to yard block at 23 hours and 13 minutes
# Vessel 1: Crane places container 123 on truck at 23 hours and 15 minutes
# Truck starts transporting container 123 to yard block at 23 hours and 15 minutes
# Truck returns to quay crane at 23 hours and 19 minutes
# Vessel 2: Crane starts unloading container 58 at 23 hours and 19 minutes
# Truck returns to quay crane at 23 hours and 21 minutes
# Vessel 1: Crane starts unloading container 124 at 23 hours and 21 minutes
# Vessel 2: Crane places container 58 on truck at 23 hours and 22 minutes
# Truck starts transporting container 58 to yard block at 23 hours and 22 minutes
# Vessel 1: Crane places container 124 on truck at 23 hours and 24 minutes
# Truck starts transporting container 124 to yard block at 23 hours and 24 minutes
# Truck returns to quay crane at 23 hours and 28 minutes
# Vessel 2: Crane starts unloading container 59 at 23 hours and 28 minutes
# Truck returns to quay crane at 23 hours and 30 minutes
# Vessel 1: Crane starts unloading container 125 at 23 hours and 30 minutes
# Vessel 2: Crane places container 59 on truck at 23 hours and 31 minutes
# Truck starts transporting container 59 to yard block at 23 hours and 31 minutes
# Vessel 1: Crane places container 125 on truck at 23 hours and 33 minutes
# Truck starts transporting container 125 to yard block at 23 hours and 33 minutes
# Truck returns to quay crane at 23 hours and 37 minutes
# Vessel 2: Crane starts unloading container 60 at 23 hours and 37 minutes
# Truck returns to quay crane at 23 hours and 39 minutes
# Vessel 1: Crane starts unloading container 126 at 23 hours and 39 minutes
# Vessel 2: Crane places container 60 on truck at 23 hours and 40 minutes
# Truck starts transporting container 60 to yard block at 23 hours and 40 minutes
# Vessel 1: Crane places container 126 on truck at 23 hours and 42 minutes
# Truck starts transporting container 126 to yard block at 23 hours and 42 minutes
# Truck returns to quay crane at 23 hours and 46 minutes
# Vessel 2: Crane starts unloading container 61 at 23 hours and 46 minutes
# Truck returns to quay crane at 23 hours and 48 minutes
# Vessel 1: Crane starts unloading container 127 at 23 hours and 48 minutes
# Vessel 2: Crane places container 61 on truck at 23 hours and 49 minutes
# Truck starts transporting container 61 to yard block at 23 hours and 49 minutes
# Vessel 1: Crane places container 127 on truck at 23 hours and 51 minutes
# Truck starts transporting container 127 to yard block at 23 hours and 51 minutes
# Truck returns to quay crane at 23 hours and 55 minutes
# Vessel 2: Crane starts unloading container 62 at 23 hours and 55 minutes
# Truck returns to quay crane at 23 hours and 57 minutes
# Vessel 1: Crane starts unloading container 128 at 23 hours and 57 minutes
# Vessel 2: Crane places container 62 on truck at 23 hours and 58 minutes
# Truck starts transporting container 62 to yard block at 23 hours and 58 minutes
